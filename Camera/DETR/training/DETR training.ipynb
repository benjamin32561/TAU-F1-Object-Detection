# %%
# !git clone https://github.com/facebookresearch/detr.git  # clone model repo
# !git clone https://github.com/benjamin32561/TAU-F1-Object-Detection.git # clone our repo

# !rm -r sample_data

# %pip install loguru
# %cd /content/TAU-F1-Object-Detection/
# !git checkout develop # moving to develop branch
# %pip install -r requirements.txt # install dependencies

# %cd /content/detr/
# %pip install -qr requirements.txt # install dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
# takes about 10 min to unzip
# !unzip -q /content/drive/MyDrive/Formula/fsoco_bounding_boxes_train.zip -d /content/dataset

# %%
# takes about 30 sec to move, xx sec to copy
# %cd '/content/TAU-F1-Object-Detection/Camera/DETR/data preprocess'
# !python cvt2detr.py
# Out:
# /content/TAU-F1-Object-Detection/Camera/DETR/data preprocess

# %%
# %cd /content/detr/
# !python main.py --coco_path /content/detr_dataset
