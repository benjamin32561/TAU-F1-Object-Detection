# %%
# !git clone https://github.com/yhenon/pytorch-retinanet.git
# !git clone https://github.com/benjamin32561/TAU-F1-Object-Detection.git # clone our repo

# !rm -r sample_data

# %pip install loguru
# %cd /content/TAU-F1-Object-Detection/
# !git checkout develop # moving to develop branch
# %pip install -r requirements.txt # install dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# takes about 10 min to unzip
# !unzip -q /content/drive/MyDrive/Formula/fsoco_bounding_boxes_train.zip -d /content/dataset

# %%
# takes about 30 sec to move
# %cd '/content/TAU-F1-Object-Detection/Camera/RetinaNet/data preprocess'
# !python cvt2retina.py

# %%
# %cd /content/pytorch-retinanet
#change ', iscrowd=False)' to ')' on /content/pytorch-retinanet/retinanet/dataloader.py in line 85
# !python train.py --dataset coco --coco_path /content/retinanet_dataset/ --depth 50
