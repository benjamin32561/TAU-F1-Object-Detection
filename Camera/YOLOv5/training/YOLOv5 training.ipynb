# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !git clone https://github.com/benjamin32561/TAU-F1-Object-Detection.git # clone repo

# !rm -r sample_data
# !apt-get install pv

# %pip install loguru
# %cd /content/TAU-F1-Object-Detection/
# !git checkout develop # moving to develop branch
# %pip install -r requirements.txt # install dependencies

# %cd /content/yolov5/
# %pip install -qr requirements.txt # install dependencies

# %%
import torch
import os

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip -q /content/drive/MyDrive/Formula/fsoco_bounding_boxes_train.zip -d /content/dataset

# %%
# %cd /content/TAU-F1-Object-Detection/Camera/YOLOv5/
# !python cvt2yolo.py

# %%
# %cd /content/yolov5/
# !python train.py --img 640 --batch 16 --epochs 1 --data /content/TAU-F1-Object-Detection/Camera/YOLOv5/yaml/dataset.yaml --weights yolov5s.pt
